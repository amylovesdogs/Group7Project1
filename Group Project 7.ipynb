# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
happiness_file = pd.read_csv ('/Users/anisabraun/Downloads/world_happiness.csv')
happiness_file.head()
# Out:
#   Country Name Regional Indicator  Year  Life Ladder  Log GDP Per Capita  \
# 0  Afghanistan         South Asia  2008     3.723590            7.350416
# 1  Afghanistan         South Asia  2009     4.401778            7.508646
# 2  Afghanistan         South Asia  2010     4.758381            7.613900
# 3  Afghanistan         South Asia  2011     3.831719            7.581259
# 4  Afghanistan         South Asia  2012     3.782938            7.660506
#
#    Social Support  Healthy Life Expectancy At Birth  \
# 0        0.450662                         50.500000
# 1        0.552308                         50.799999
# 2        0.539075                         51.099998
# 3        0.521104                         51.400002
# 4        0.520637                         51.700001
#
#    Freedom To Make Life Choices  Generosity  Perceptions Of Corruption  \
# 0                      0.718114    0.167652                   0.881686
# ...

# %%
filter = happiness_file.Year == 2022
happiness_file[['Country Name', 'Life Ladder', 'Healthy Life Expectancy At Birth','Year']]
happiness_file[filter]
# Out:
#      Country Name                  Regional Indicator  Year  Life Ladder  \
# 13    Afghanistan                          South Asia  2022     1.281271
# 28        Albania          Central and Eastern Europe  2022     5.212213
# 59      Argentina         Latin America and Caribbean  2022     6.260993
# 75        Armenia  Commonwealth of Independent States  2022     5.381943
# 91      Australia               North America and ANZ  2022     7.034696
# ...           ...                                 ...   ...          ...
# 2104      Uruguay         Latin America and Caribbean  2022     6.670853
# 2120   Uzbekistan  Commonwealth of Independent States  2022     6.016239
# 2137    Venezuela         Latin America and Caribbean  2022     5.948992
# 2154      Vietnam                      Southeast Asia  2022     6.266509
# 2198     Zimbabwe                  Sub-Saharan Africa  2022     3.296220
#
#       Log GDP Per Capita  Social Support  Healthy Life Expectancy At Birth  \
# ...

# %%
plt.scatter(x='Healthy Life Expectancy At Birth', y='Life Ladder', data=happiness_file)
plt.title("Healthy Life Expectancy At Birth vs. Life Lader For the Year 2022")
plt.xlabel("Healthy Life Expectancy At Birth")
plt.ylabel("Life Ladder")
plt.show()

# %%
plt.hist(x='Healthy Life Expectancy At Birth', data=happiness_file)
plt.title("Healthy Life Expectancy At Birth vs. Life Lader For the Year 2022")
plt.xlabel("Healthy Life Expectancy At Birth")
plt.ylabel("Life Ladder")
plt.show()
